# %%
import pandas as pd
import csv 
import json
import os
import numpy as np

# %%
new = pd.DataFrame()

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'catch.ipynb',
#  'classifier.ipynb',
#  'classifier2.ipynb',
#  'cleardata.ipynb',
#  'coordinate.ipynb',
#  'create RAWDATA.ipynb',
#  'MRTcatch.ipynb',
#  'Scrap_using_Selenium_Multithread.py',
#  'test',
#  'test.ipynb',
#  'test1.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  '分筆數.ipynb',
#  '座標.ipynb',
#  '把資料庫丟到mysql.ipynb',
#  '把資料集合.ipynb',
#  '抓取單個欄位.ipynb',
#  '整理.ipynb',
#  '補充資料.ipynb']

# %%
for j in os.listdir('C:/Users/ayakashi/Desktop/tableau_專題呈現/MRT'):
    print(j)
# Out:
# mrt-Y15.xlsx
# mrt-Y16.xlsx
# mrt-Y17.xlsx
# mrt-Y18.xlsx
# mrt-Y19.xlsx
# mrt-Y20.xlsx

# %%
for j in os.listdir('C:/Users/ayakashi/Desktop/tableau_專題呈現/MRT'):
    new_1 = pd.read_excel(f'C:/Users/ayakashi/Desktop/tableau_專題呈現/MRT/{j}')
    new = pd.concat([new,new_1],ignore_index=True)

# %%
new.drop(columns={"Unnamed: 0"})
# Out:
#             No     name(web)                  address   大分類       小分類  \
# 0         ma56          埔墘市場                      民享街    市場      傳統市場
# 1         ma74        板橋興隆市場                  民享街152號    市場      傳統市場
# 2      s014604        市立埔墘國小      [220]新北市板橋區永豐街42之8號    學校        國小
# 3      s014607        市立海山國小      [220]新北市板橋區漢生東路280號    學校        國小
# 4      s014505        市立中山國中  [220]新北市板橋區文化路一段188巷56號    學校        國中
# ...        ...           ...                      ...   ...       ...
# 11047   193057     龍火鮮烘咖啡福前店                  福前街263號  咖啡簡餐       咖啡店
# 11048   258683        龍城燒臘快餐            號, No. 70五權一路    異國  異國料理-港/粵
# 11049   258148         營養早餐店               五工二路86巷54號    早餐        早餐
# 11050   180655         關渡古錐ㄟ              五工三路94巷4號1樓   飲料店       飲料店
# 11051   180743  鬍鬚張魯肉飯 五股五權店                  五權一路10號    台式        台式
#
#                      coordinate   latitude   longitude COUNTYNAME mrt_name
# ...

# %%
new.to_csv("C:/Users/ayakashi/Desktop/tableau_專題呈現/test_1.csv")

# %%
new
# Out:
#        Unnamed: 0       No     name(web)                  address   大分類  \
# 0              55     ma56          埔墘市場                      民享街    市場
# 1              73     ma74        板橋興隆市場                  民享街152號    市場
# 2             194  s014604        市立埔墘國小      [220]新北市板橋區永豐街42之8號    學校
# 3             197  s014607        市立海山國小      [220]新北市板橋區漢生東路280號    學校
# 4             549  s014505        市立中山國中  [220]新北市板橋區文化路一段188巷56號    學校
# ...           ...      ...           ...                      ...   ...
# 11047       63954   193057     龍火鮮烘咖啡福前店                  福前街263號  咖啡簡餐
# 11048       64010   258683        龍城燒臘快餐            號, No. 70五權一路    異國
# 11049       64272   258148         營養早餐店               五工二路86巷54號    早餐
# 11050       66038   180655         關渡古錐ㄟ              五工三路94巷4號1樓   飲料店
# 11051       66098   180743  鬍鬚張魯肉飯 五股五權店                  五權一路10號    台式
#
#             小分類                coordinate   latitude   longitude COUNTYNAME  \
# ...
